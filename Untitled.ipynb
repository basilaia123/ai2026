# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.74.1)
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (2.12.4)
# Requirement already satisfied: sniffio in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\GBASILAIA\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
ANTHROPIC_API_KEY="your-api-key-here"

# %%
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "What is quantum computing? Answer in one sentence"
        }
    ]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 message = client.messages.create(
#       2     model=model,
#       3     max_tokens=1000,
#       4     messages=[
#
# NameError: name 'client' is not defined
